# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %% [markdown]
# # Importing data

# %%
path = r'C:\Users\thoma\OneDrive\Dokumente\data analytics\ML_Ach1\ClimateWins'

# %%
path
# Out:
# 'C:\\Users\\thoma\\OneDrive\\Dokumente\\data analytics\\ML_Ach1\\ClimateWins'

# %%
df = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'PCA(143).csv'))

# %% [markdown]
# # Hirarchical Clustering - using the reduced data

# %% [markdown]
# # Scaled Single Method - PCA(143) data (2015)

# %%
distance_single = linkage(df, method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %% [markdown]
# # -> Less granulated but still 1 cluster

# %% [markdown]
# # Scaled Complete Method - PCA data (2015)

# %%
distance_complete = linkage(df, method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %% [markdown]
# # -> Less granulated & 2 clusters instead of 3 in the original form

# %% [markdown]
# # Scaled Average Method - PCA(143) data (2015)

# %%
distance_average = linkage(df, method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %% [markdown]
# # -> Less granulated - 2 clusters - seems to perform better in this reduced form

# %% [markdown]
# # Scaled Ward Method - PCA(143) data (2015)

# %%
distance_ward = linkage(df, method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()

# %% [markdown]
# # -> 2 clusters

# %% [markdown]
# # PCA with 15 components

# %%
# Importing data
df2 = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'PCA(15).csv'))

# %% [markdown]
# # Scaled Single Method - PCA(15) data (2015)

# %%
distance_single = linkage(df2, method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Single Method",fontsize=18)
plt.show()

# %% [markdown]
# # Scaled Complete Method - PCA(15) data (2015)

# %%
distance_complete = linkage(df2, method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Complete Method",fontsize=18)
plt.show()

# %% [markdown]
# # Scaled Average Method - PCA(15) data (2015)

# %%
distance_average = linkage(df2, method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Average Method",fontsize=18)
plt.show()

# %% [markdown]
# # Scaled Ward Method - PCA(15) data (2015)

# %%
distance_ward = linkage(df2, method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("Dendrogram Ward Method",fontsize=18)
plt.show()

# %% [markdown]
# # -> Reducing to 15 components doesn't seem to make a difference in the number of clusters

# %% [markdown]
# # Overall, it seems that the year can be split into 2 seasons
